# %% [markdown]
# <a href="https://colab.research.google.com/github/JUHYUNCHOI/Python-Data-Analysis-and-Image-Processing-Tutorial/blob/master/Upper%26Lower%EC%88%99%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 설명

# %% [markdown]
# **시퀀스 자료형의 일부분을 잘라내는 것을 슬라이싱이라고 합니다.**
#
# **[시작하는 인덱스(포함): 끝나는 인덱스(불포함)]**
#
#
# 문자열(s**tring)**
#
# ![스크린샷 2023-07-04 오후 9.09.53.png](data:image/png;base64,...)
#
# ```python
# >>> s = 'julia'
# >>> s[1:3]   # 인덱스 1부터 2까지 자름
# 'ul'
# ```
#
# **생략하여 사용하는 방법:**
#
# - **시퀀스자료형[**시작하는 인덱스(포함**): ]**
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ```python
# >>> s = 'julia'
# >>> s[3:]   # 인덱스 3부터 끝까지
# 'ia'
# ```
#
# 시퀀스자료형[ : 끝나는 인덱스(불포함)]
#
# ![image.png](data:image/png;base64,...)
#
# ```python
# >>> s = 'julia'
# >>> s[:3]   # 인덱스 0부터 2까지
# 'jul'
# ```

# %% [markdown]
# # 문제

# %% [markdown]
# 1. 다음 기린학교의 학생들 명단입니다. 모두 대문자로 출력하도록 코드를 완성하세요.
#
# students = ['julia', 'girin', 'james', 'Conan']
#
# 결과:
# JULIA
# GIRIN
# JAMES
# CONAN

# %%
# 다음 코드를 완성하세요.

students = ['julia', 'girin', 'james', 'Conan']

# %% [markdown]
# 2. 다음 기린학교의 학생들 명단입니다. 모두 소문자로 출력하도록 코드를 완성하세요.
# students = ['julia', 'girin, 'james', 'Conan']
#
# 결과: julia girin james conam

# %%
# 다음 코드를 완성하세요.

students = ['julia', 'girin', 'james', 'Conan']

# %% [markdown]
# 3. 다음 기린학교의 학생들 명단입니다. 첫글자만 대문자로 출력하도록 코드를 완성하세요.
#
# students = ['julia', 'girin', 'james', 'Conan'].
# 결과:
# Julia
# Girin
# James
# Conan

# %%
# 답

# %% [markdown]
# 아래 문제는 배운 내용과 관련 없는 문제입니다. 3급 시험문제를 대비한 문제이니 잘 풀어보세요^^ 어렵습니다. 잘 고민해 보는 시간을 가졌으면 좋겠습니다.
#
# ### 문제 11
#
# k에 3씩 더하여 크기가 작은 순으로 n개 출력하려 합니다.
#
# 두 자연수 k와 n을 전달받아, k에 3씩 더하여 크기가 작은 순서대로 n개 출력해 주세요.
#
#
# ### 입력 설명
# 두 자연수 k와 n이 주어집니다.
#
# * k는 2 이상 100 이하인 자연수입니다.
# * n은 1 이상 100 이하인 자연수입니다.
#
# ### 출력 설명
# k에 3씩 더하여 크기가 작은 순서대로 n개 만큼 출력해주세요.
#
# ### 예제
# | k | n | result |
# | :--: | :--: | :-- |
# | 7 | 5 | 7 10 13 16 19 |
# | 3 | 4 | 3 6 9 12 |
#
# ### 예제 설명
#
# <예제 #1>
# 7에서부터 3씩 더한 5개를 나열하면 7 10 13 16 19입니다.
#
# <예제 #2>
# 3에서부터 3씩 더한 4개를 나열하면 3 6 9 12입니다.

# %%
# 답)
