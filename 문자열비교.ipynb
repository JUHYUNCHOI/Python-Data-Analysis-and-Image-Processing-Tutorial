# %% [markdown]
# <a href="https://colab.research.google.com/github/JUHYUNCHOI/Python-Data-Analysis-and-Image-Processing-Tutorial/blob/master/%EB%AC%B8%EC%9E%90%EC%97%B4%EB%B9%84%EA%B5%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 컴퓨터에서 모든 데이터는 숫자로 표현됩니다. 즉, 문자열도 글자가 아닌 숫자로 표현되지요. 예를 들면 문자 'A'는 65로, 'B'는 66으로 표현합니다. 그리고 각 문자들은 정해진 숫자가 있는데, 이를 아스키(ASCII)문자라고 합니다.
#
#
# 아래 아스키 문자를 관찰하다보면 'A'에서 'B'로 갈수록 숫자가 커지고, 'a'에서 'b'로 갈 수록 숫자가 커집니다. 이를 이용해서 알파벳 순서를 알애낼 수가 있습니다.
#
# 'A'와 'Z'중 어느 수가 더 클까요? 아스키코드를 보면 'A'는 65이고 'Z'는 90입니다.

# %% [markdown]
# ### 아스키(ASCII)문자
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그렇다면 아래 코드의 결과는 True일까요 False일까요?
#
# ```
# 'A' < 'Z'
# ```
#
# 네 맞습니다. 이 코드의 결과는 True입니다.
#
# 이제 여러분들이 아래 코드의 각 결과를 생각해 보세요.
# ```
# 'B' > 'D'
# 'F' < 'Z'
# 'd' > 'e'
# 'g' > 'a'
# 'k' < 'o'
# ```
#
#
#
#
#
# ---------
#
#
# 정답을 알아볼까요?
# ```
# 'B' > 'D'   # False
# 'F' < 'Z'   # True
# 'd' > 'e'   # False
# 'g' > 'a'   # True
# 'k' < 'o'   # True
# ```

# %% [markdown]
# 이를 이용하여 문자열을 비교하는 코드를 작성하려고 합니다.

# %% [markdown]
# # 문제1

# %% [markdown]
# 다음 각 줄의 결과는 True일까요? False일까요?
#
#
#
# 1. 'd' < 'p'
# 2. 'apple' < 'zoo'
# 3. 'white' > 'flower'
# 4. 'D' < 'd'
# 5. 't' == 'T'

# %% [markdown]
# 답을 이곳에 입력하시오.
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# # 문제2

# %% [markdown]
# 두개의 문자를 입력받아 먼저 나오는 단어를 출력하세요.
#
#    입력예제:
#        'a'
#        'z'
#    출력예제:
#        'a'

# %%
# 답을 이곳이 입력하시오.

# %% [markdown]
# # 문제3

# %% [markdown]
# 위 문제는 같은 소문자끼리 비교하는 문제였습니다. 그렇다면 소문자 'a'와 대문자 'A'를 비교하였을 경우는 어떨까요?   'a'는 ASCII 문자에서 97이고 'A'는 65입니다. 그래서 'a'와 'A'를 다음과 같이 비교하였을 경우 그 값은 False입니다.
#
# ```
# 'A' > 'a'
# ```
# ('A' > 'a'는 컴퓨터에서 65 > 97로 바뀜)
#
# 그래서 'apple'과 'Zoo' 중 어느 단어가 사전에서 먼저 나오냐고 아래와 같이 묻는다면 결과는 'Zoo'가 될 것 입니다.
#
# ```
# if 'apple' < 'Zoo':
#     print('apple')
# else:
#     print('Zoo')
# ```
#
# 결과:
# ```
# Zoo
# ```
#
# (Zoo의 Z가 대문자이기 때문에 소문자인 a보다 숫자가 작음)
#
# 대문자와 소문자의 숫자가 다르기 때문에 생기는 문제를 해결하기 위해 우리는 모두 대문자 또는 소문자로 바꾸어 비교해 줍니다.
# 대문자로 바꾸는 명령어는 문자열.upper()이고 소문자로 바꾸는 명령어는 문자열.lower()입니다.
#
#
# ```
# if 'apple'.upper() < 'Zoo'.upper():
#     print('apple')
# else:
#     print('Zoo')
# ```
#
# **다음 입력받은 두 단어에 upper()를 사용하여 사전에서 먼저 나오는 단어를 출력하세요. **
#
# 입력예제:
# ```
# apple
# Zoo
# ```
#
# 출력예제:
# ```
# apple
# ```

# %%
a = input()
b = input()


# 다음 코드를 완성하시오.
